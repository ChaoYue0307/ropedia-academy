# %% [markdown]
# # Ropedia Academy — C5 · Hand detection & segmentation
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ChaoYue0307/ropedia-academy/blob/main/notebooks/C5.ipynb)
#
# > **First-person geometry: own hands enter from the bottom — a strong prior for detection.**
# >
# > 第一人称几何：自己的手从底部进入——检测的强先验。
#
# This is the core snippet from the lesson — read it, run it, and tinker. Colab's default runtime already includes `torch`, `numpy`, `cv2`, and `networkx`, so just press **Run**.
#
# Some snippets are deliberately minimal: where you see `...` or names like `model` / `loader` / `smpl`, plug in your own data to extend the example.
#
# 🔗 Full lesson (with the interactive demo & key terms): https://chaoyue0307.github.io/ropedia-academy/lesson/C5

# %%
# the wearer's own hands enter from the bottom edge -- a strong prior
def is_own_hand(box, H):           # box = (x1, y1, x2, y2)
    return box[3] > 0.8 * H         # bottom of box near the frame bottom

def side(box, W):                  # left vs right by horizontal position
    return "left" if (box[0] + box[2]) / 2 < W / 2 else "right"

# %% [markdown]
# ### Where to go next
#
# - Swap the toy tensors for a real batch and watch the shapes flow through.
# - Open the matching lesson for the math and an interactive figure: https://chaoyue0307.github.io/ropedia-academy/lesson/C5
# - Browse every notebook: https://github.com/ChaoYue0307/ropedia-academy/tree/main/notebooks

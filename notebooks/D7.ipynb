# %% [markdown]
# # Ropedia Academy — D7 · Spatial reasoning
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ChaoYue0307/ropedia-academy/blob/main/notebooks/D7.ipynb)
#
# > **Spatial reasoning must commit to a reference frame; conversions are the same rotation discipline as Track A/B.**
# >
# > 空间推理须确定参照系；坐标转换与 Track A/B 是同一套旋转纪律。
#
# This is the core snippet from the lesson — read it, run it, and tinker. Colab's default runtime already includes `torch`, `numpy`, `cv2`, and `networkx`, so just press **Run**.
#
# Some snippets are deliberately minimal: where you see `...` or names like `model` / `loader` / `smpl`, plug in your own data to extend the example.
#
# 🔗 Full lesson (with the interactive demo & key terms): https://chaoyue0307.github.io/ropedia-academy/lesson/D7

# %%
import numpy as np

# "left of the chair" depends on the frame -- convert ego <-> world
def world_to_ego(p_world, cam_R, cam_t):
    return cam_R.T @ (p_world - cam_t)      # into the camera's frame

def ego_to_world(p_ego, cam_R, cam_t):
    return cam_R @ p_ego + cam_t            # back to the world frame

# %% [markdown]
# ### Where to go next
#
# - Swap the toy tensors for a real batch and watch the shapes flow through.
# - Open the matching lesson for the math and an interactive figure: https://chaoyue0307.github.io/ropedia-academy/lesson/D7
# - Browse every notebook: https://github.com/ChaoYue0307/ropedia-academy/tree/main/notebooks

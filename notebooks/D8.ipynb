# %% [markdown]
# # Ropedia Academy — D8 · World models
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ChaoYue0307/ropedia-academy/blob/main/notebooks/D8.ipynb)
#
# > **A world model is learned dynamics — plan by imagining rollouts and picking the best.**
# >
# > 世界模型即学到的动力学——通过想象滚动并择优来规划。
#
# This is the core snippet from the lesson — read it, run it, and tinker. Colab's default runtime already includes `torch`, `numpy`, `cv2`, and `networkx`, so just press **Run**.
#
# Some snippets are deliberately minimal: where you see `...` or names like `model` / `loader` / `smpl`, plug in your own data to extend the example.
#
# 🔗 Full lesson (with the interactive demo & key terms): https://chaoyue0307.github.io/ropedia-academy/lesson/D8

# %%
# a world model PREDICTS the future, so you can plan by imagining
def imagine(state, plan, dynamics, reward):
    total = 0.0
    for action in plan:                  # roll the future forward
        state = dynamics(state, action)  # learned transition
        total += reward(state)
    return total

best = max(candidate_plans, key=lambda p: imagine(s0, p, dynamics, reward))

# %% [markdown]
# ### Where to go next
#
# - Swap the toy tensors for a real batch and watch the shapes flow through.
# - Open the matching lesson for the math and an interactive figure: https://chaoyue0307.github.io/ropedia-academy/lesson/D8
# - Browse every notebook: https://github.com/ChaoYue0307/ropedia-academy/tree/main/notebooks
